# %% [markdown]
# # KYC Feature Engineering and EDA
#
# Independent EDA using the cleaned dataset only. No joins or combined datasets are used.

# %%
from analyze_fintech_data import ensure_directories, run_kyc_analysis
ensure_directories()
df = run_kyc_analysis()
df.head()

# %% [markdown]
# ## Feature output and descriptive statistics

# %%
df.to_csv('data/processed/kyc_featured.csv', index=False)
df.describe(include='all').T

# %% [markdown]
# ## Findings
# See `reports/kyc_key_findings.md` for generated frequency tables, outlier findings, suspicious-pattern flags, and business insights.
