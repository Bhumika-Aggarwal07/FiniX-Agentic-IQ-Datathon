# %% [markdown]
# # Chargebacks — Exploratory Data Analysis
#
# ## Objective
#
# Analyze chargeback behaviour and investigate the relationship between
# Chargebacks and Transactions.
#
# ### Key areas
# - Reason codes
# - Severity
# - Resolution status
# - Channel
# - Disputed amounts
# - User and merchant chargeback patterns
# - Date/time patterns
# - Chargeback–Transaction relationships

# %%
import pandas as pd

# Load feature-engineered Chargebacks data
df = pd.read_csv("../data/processed/chargeback_features.csv")

# Most common chargeback reasons
reason_counts = df["reason_code"].value_counts()

print("Chargeback Reason Code Distribution:")
print(reason_counts)
